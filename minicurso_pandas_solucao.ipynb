# %% [markdown]
# # Introdução à Análise de Dados com Pandas

# %% [markdown]
# Material baseado no tutorial "Seus primeiros passos como Data Scientist: Introdução ao Pandas!", que pode ser encontrado [aqui](https://medium.com/data-hackers/uma-introdu%C3%A7%C3%A3o-simples-ao-pandas-1e15eea37fa1)

# %% [markdown]
# **Pandas** é uma biblioteca Python que fornece ferramentas de análise de dados e estruturas de dados de alta performance e *fáceis de usar*. Por ser a principal e mais completa biblioteca para estes objetivos, **pandas** é fundamental para análise de dados com Python.
#
# Objetivo do minicurso é fornecer de forma enxuta e simplificada, uma apresentação básica às principais ferramentas fornecidas pelo **pandas**, cobrindo:
#
# - Manipulação;
# - Leitura; e,
# - Visualização de dados

# %% [markdown]
# ### Importando as bibliotecas:

# %%
## Importando as bibliotecas
import pandas as pd
import numpy as np

# %% [markdown]
# Existem dois tipos principais de estruturas de dados no pandas:
#  1. **Series**
#  1. **DataFrame**

# %% [markdown]
# ## Series
#
# Uma Series é como um array unidimensional, uma lista de valores. Toda Series possui um índice, o `index`, que dá rótulos a cada elemento da lista. Abaixo criamos uma Series `notas`, o `index` desta Series é a coluna à esquerda, que vai de 0 a 4 neste caso, que o pandas criou automaticamente, já que não especificamos uma lista de rótulos.

# %%
## Criando uma series
notas = pd.Series([2,8,9,7,6])

# %% [markdown]
# Já podemos aqui verificar os atributos da nossa Series, comecemos pelos valores e o índice, os dois atributos *fundamentais* nesta estrutura:

# %%
# values
notas
# Out:
# 0    2
# 1    8
# 2    9
# 3    7
# 4    6
# dtype: int64

# %%
# index
notas.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# Como ao criar a Series não demos um índice específico o pandas usou os inteiros positivos crescentes como padrão. Pode ser conveniente atribuirmos um índice diferente do padrão, supondo que essas sejam notas de uma turma, poderíamos atribuir nomes ao index:

# %%
## Criando uma series com índices definidos

notas = pd.Series([2,8,9,7,6],index=['Mark', 'Richard', 'Julia', 'Robert', 'Gracie'])
notas
# Out:
# Mark       2
# Richard    8
# Julia      9
# Robert     7
# Gracie     6
# dtype: int64

# %% [markdown]
# O index nos ajuda para referenciar um determinado valor, ele nos permite acessar os valores pelo seu rótulo:

# %%
## Acessando valores
notas['Mark']
# Out:
# 2

# %% [markdown]
# Outra facilidade proporcionada pela estrutura são seus métodos que fornecem informações estatísticas sobre os valores, como **média** `.mean()` e **desvio padrão** `.std()`.

# %%
## Verificando média e desvio padrão
print(notas.mean())
print(notas.std())
# Out:
# 6.4
# 2.701851217221259

# %% [markdown]
# Geralmente para resumir brevemente as estatísticas dos dados se usa o `.describe()`

# %%
## Utilizar a função describe()
notas.describe()
# Out:
# count    5.000000
# mean     6.400000
# std      2.701851
# min      2.000000
# 25%      6.000000
# 50%      7.000000
# 75%      8.000000
# max      9.000000
# dtype: float64

# %% [markdown]
# A estrutura é flexível o suficiente pra aplicarmos algumas expressões matemáticas e funções matemáticas do numpy diretamente:

# %%
## Multiplicação e log (np.log())
print(np.log(notas))
# Out:
# Mark       0.693147
# Richard    2.079442
# Julia      2.197225
# Robert     1.945910
# Gracie     1.791759
# dtype: float64

# %% [markdown]
# ## DataFrame
# Já um DataFrame é uma estrutura bidimensional de dados, como uma planilha.

# %%
## Criando um DataFrame
df = pd.DataFrame({'Aluno': ['Mark', 'Richard', 'Julia', 'Robert', 'Gracie'],
                   'Nota Prova': [5,5,8,7,6.5],
                   'Nota Seminário': [10,8,9.25,8,9.9],
                   'Faltas': [0,0,2,8,1]
                  })
df
# Out:
#      Aluno  Nota Prova  Nota Seminário  Faltas
# 0     Mark         5.0           10.00       0
# 1  Richard         5.0            8.00       0
# 2    Julia         8.0            9.25       2
# 3   Robert         7.0            8.00       8
# 4   Gracie         6.5            9.90       1

# %% [markdown]
# Verificando os tipos de dados que compõe as colunas.

# %%
## Tipo dos dados
df.dtypes
# Out:
# Aluno              object
# Nota Prova        float64
# Nota Seminário    float64
# Faltas              int64
# dtype: object

# %% [markdown]
# É possível acessar a lista de colunas de forma bem intuitiva:

# %%
## Colunas do DataFrame
df.columns
# Out:
# Index(['Aluno', 'Nota Prova', 'Nota Seminário', 'Faltas'], dtype='object')

# %% [markdown]
# Os nomes das colunas podem ser usadas pra acessar seus valores:

# %%
## Acessando valores
df["Nota Seminário"]
# Out:
# 0    10.00
# 1     8.00
# 2     9.25
# 3     8.00
# 4     9.90
# Name: Nota Seminário, dtype: float64

# %% [markdown]
# Para DataFrames, `.describe()` também é uma boa forma de verificar resumidamente a disposição estatística dos dados numéricos:

# %%
## Utilizar a função describe()
df.describe()
# Out:
#        Nota Prova  Nota Seminário   Faltas
# count     5.00000        5.000000  5.00000
# mean      6.30000        9.030000  2.20000
# std       1.30384        0.983362  3.34664
# min       5.00000        8.000000  0.00000
# 25%       5.00000        8.000000  0.00000
# 50%       6.50000        9.250000  1.00000
# 75%       7.00000        9.900000  2.00000
# max       8.00000       10.000000  8.00000

# %% [markdown]
# Outra tarefa comum aplicada em DataFrames é ordená-los por determinada coluna:

# %%
## Ordenando pelas notas do seminário
df.sort_values(by="Nota Seminário")
# Out:
#      Aluno  Nota Prova  Nota Seminário  Faltas
# 1  Richard         5.0            8.00       0
# 3   Robert         7.0            8.00       8
# 2    Julia         8.0            9.25       2
# 4   Gracie         6.5            9.90       1
# 0     Mark         5.0           10.00       0

# %% [markdown]
# Note que simplesmente usar o método `sort_values` não modifica o nosso DataFrame original:

# %%
## Visualizando DataFrame
df
# Out:
#      Aluno  Nota Prova  Nota Seminário  Faltas
# 0     Mark         5.0           10.00       0
# 1  Richard         5.0            8.00       0
# 2    Julia         8.0            9.25       2
# 3   Robert         7.0            8.00       8
# 4   Gracie         6.5            9.90       1

# %% [markdown]
# Muitas vezes é necessário selecionarmos valores específicos de um DataFrame, seja uma linha ou uma célula específica, e isso pode ser feito de diversas formas.

# %% [markdown]
# Para selecionar pelo index ou rótulo usamos o atributo `.loc`:

# %%
## Acessando index pelo .loc[]
df.loc[3]
# Out:
# Aluno             Robert
# Nota Prova             7
# Nota Seminário         8
# Faltas                 8
# Name: 3, dtype: object

# %% [markdown]
# Para selecionar de acordo com critérios condicionais, se usa o que se chama de **Boolean Indexing**.
#
# Suponha que queiramos selecionar apenas as linhas em que o valor da coluna *Seminário* seja acima de 8.0:

# %%
## Boolean Indexing
df[df['Nota Seminário'] > 8]
# Out:
#     Aluno  Nota Prova  Nota Seminário  Faltas
# 0    Mark         5.0           10.00       0
# 2   Julia         8.0            9.25       2
# 4  Gracie         6.5            9.90       1

# %% [markdown]
# Este tipo de indexação também possibilita checar condições de múltiplas colunas. Diferentemente do que estamos habituados em Python, aqui se usam operadores bitwise, ou seja, `&`, `|`, `~` ao invés de `and`, `or`, `not`, respectivamente. Suponha que além de `df["Seminário"] > 8.0` queiramos que o valor da coluna `Prova` não seja menor que 3:

# %%
## Boolean Indexing e condições
df[(df['Nota Seminário'] > 8) & (df['Nota Prova'] >= 3)]
# Out:
#     Aluno  Nota Prova  Nota Seminário  Faltas
# 0    Mark         5.0           10.00       0
# 2   Julia         8.0            9.25       2
# 4  Gracie         6.5            9.90       1

# %% [markdown]
# ## Leitura de *datasets*

# %% [markdown]
# O pandas nos fornece uma série de funcionalidades de leitura de dados, pros mais diversos formatos estruturais de dados, experimente a auto-completação de `pd.read_<TAB>`, entre eles estão:
#  1. `pd.read_csv`, para ler arquivos .csv, formato comum de armazenar dados de tabelas
#  1. `pd.read_xlsx`, para ler arquivos Excel .xlsx, é necessário instalar uma biblioteca adicional pra esta funcionalidade.
#
# Usaremos para analisar dados externos nesta introdução o `.read_csv`, pois é neste formato que se encontram nossos dados.
#
# Estes dados que usaremos como exemplo são dados que contêm informações de 802 pokemons de todas as sete gerações. O arquivo pode ser encontrado [aqui](https://www.kaggle.com/rounakbanik/pokemon)

# %%
## Lendo um dataset
df1 = pd.read_csv('googleplaystore_user_reviews.csv')
df2 = pd.read_csv('googleplaystore.csv')
df = df2

# %% [markdown]
# Como esperado, o DataFrame tem muitas linhas de dados, pra visualizar sucintamente as primeiras linhas de um DataFrame existe o método `.head()`

# %%
## Shape
print(len(df1))
print(len(df2))
# Out:
# 64295
# 10841

# %%
## Visualizando o dataset
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
# 5      167  5.6M      50,000+  Free     0       Everyone
# 6      178   19M      50,000+  Free     0       Everyone
# 7    36815   29M   1,000,000+  Free     0       Everyone
# 8    13791   33M   1,000,000+  Free     0       Everyone
# 9      121  3.1M      10,000+  Free     0       Everyone
#
#                       Genres        Last Updated         Current Ver  \
# 0               Art & Design     January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play    January 15, 2018               2.0.0
# 2               Art & Design      August 1, 2018               1.2.4
# 3               Art & Design        June 8, 2018  Varies with device
# 4    Art & Design;Creativity       June 20, 2018                 1.1
# 5               Art & Design      March 26, 2017                 1.0
# 6               Art & Design      April 26, 2018                 1.1
# 7               Art & Design       June 14, 2018            6.1.61.1
# 8               Art & Design  September 20, 2017               2.9.2
# 9    Art & Design;Creativity        July 3, 2018                 2.8
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up
# 5    2.3 and up
# 6  4.0.3 and up
# 7    4.2 and up
# 8    3.0 and up
# 9  4.0.3 and up

# %% [markdown]
# Por padrão `.head()` exibe as 5 primeiras linhas, mas isso pode ser alterado:

# %%
## Definir quantidade de linhas
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size     Installs  Type Price  \
# 10836     4.5       38                 53M       5,000+  Free     0
# 10837     5.0        4                3.6M         100+  Free     0
# 10838     NaN        3                9.5M       1,000+  Free     0
# 10839     4.5      114  Varies with device       1,000+  Free     0
# 10840     4.5   398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
#DEBUG
df[(df['Category'] == 'TOOLS')]
# Out:
#                                                      App Category  Rating  \
# 3233                                   Moto File Manager    TOOLS     4.1
# 3234                                              Google    TOOLS     4.4
# 3235                                    Google Translate    TOOLS     4.4
# 3236                                        Moto Display    TOOLS     4.2
# 3237                                      Motorola Alert    TOOLS     4.2
# 3238                                     Motorola Assist    TOOLS     4.1
# 3239   Cache Cleaner-DU Speed Booster (booster & clea...    TOOLS     4.5
# 3240                                  Moto Suggestions ™    TOOLS     4.6
# 3241                                          Moto Voice    TOOLS     4.1
# 3242                                          Calculator    TOOLS     4.3
# 3243                                         Device Help    TOOLS     4.2
# 3244                                     Account Manager    TOOLS     4.1
# 3245                                             myMetro    TOOLS     4.0
# 3246                                        File Manager    TOOLS     4.6
# 3247                                           My Telcel    TOOLS     3.1
# 3248   Calculator - free calculator, multi calculator...    TOOLS     4.6
# 3249                                 ASUS Sound Recorder    TOOLS     4.5
# 3250                                  iWnn IME for Nexus    TOOLS     3.2
# 3251     Samsung Max - Data Savings & Privacy Protection    TOOLS     4.3
# 3252                           Android TV Remote Service    TOOLS     NaN
# 3253                                          ZenUI Help    TOOLS     4.6
# 3254   Calculator - free calculator ,multi calculator...    TOOLS     4.4
# 3255                          SHAREit - Transfer & Share    TOOLS     4.6
# 3256                       ZenUI Keyboard – Emoji, Theme    TOOLS     4.5
# 3257     Files Go by Google: Free up space on your phone    TOOLS     4.6
# 3258                                      SD card backup    TOOLS     NaN
# 3259                                Nokia mobile support    TOOLS     4.4
# 3260   File Manager -- Take Command of Your Files Easily    TOOLS     4.2
# 3261                                  Samsung Calculator    TOOLS     4.4
# 3262                                               Clear    TOOLS     3.1
# ...                                                  ...      ...     ...
# 10472            Life Made WI-Fi Touchscreen Photo Frame    TOOLS     1.9
# 10473                            osmino Wi-Fi: free WiFi    TOOLS     4.2
# 10475                                   Wi-Fi Visualizer    TOOLS     3.9
# 10485                   HD Wallpaper - Toyota FJ Cruiser    TOOLS     NaN
# 10488                                        FJ WiFi HDD    TOOLS     NaN
# 10510                                            FJ-link    TOOLS     NaN
# 10517                                         FJ Toolkit    TOOLS     NaN
# 10531                 Kernel Manager for Franco Kernel ✨    TOOLS     4.8
# 10566                              FK Crvena Zvezda Izzy    TOOLS     4.8
# 10580                                        Florida 511    TOOLS     3.2
# 10591   Lottery Ticket Checker - Florida Results & Lotto    TOOLS     1.0
# 10676                                      Calculator Fn    TOOLS     NaN
# 10688                                    Fo File Manager    TOOLS     4.5
# 10727                        Fon WiFi App – WiFi Connect    TOOLS     4.1
# 10728  MOD-MASTER for Minecraft PE (Pocket Edition) Free    TOOLS     4.2
# 10732                                 Draw with FP sDraw    TOOLS     4.3
# 10741                           Fingerprint Quick Action    TOOLS     4.2
# 10746                                         FP Opgaver    TOOLS     NaN
# 10750                            Finger Scanner Gestures    TOOLS     4.2
# 10756                   FreedomPop Friends for Free Data    TOOLS     4.4
# 10757                       Fisher-Price® Smart Connect™    TOOLS     2.7
# 10758                      Fingerprint Lock Screen Prank    TOOLS     4.1
# 10759                                     FP NFC Rewrite    TOOLS     NaN
# 10766                             FreedomPop Diagnostics    TOOLS     2.9
# 10786                                      ChopAssistant    TOOLS     4.2
# 10795                           Reindeer VPN - Proxy VPN    TOOLS     4.2
# 10796   Inf VPN - Global Proxy & Unlimited Free WIFI VPN    TOOLS     4.7
# 10800                                          FR Roster    TOOLS     4.1
# 10807                                          My FR App    TOOLS     NaN
# 10817                               HTC Sense Input - FR    TOOLS     4.0
#
#         Reviews                Size        Installs  Type  Price  \
# 3233      38655                5.9M     10,000,000+  Free      0
# 3234    8033493  Varies with device  1,000,000,000+  Free      0
# 3235    5745093  Varies with device    500,000,000+  Free      0
# 3236      18239  Varies with device     10,000,000+  Free      0
# 3237      24199                3.9M     50,000,000+  Free      0
# 3238      37333  Varies with device     50,000,000+  Free      0
# 3239   12759663                 15M    100,000,000+  Free      0
# 3240        308                4.3M      1,000,000+  Free      0
# 3241      33216  Varies with device     10,000,000+  Free      0
# 3242      40770  Varies with device    100,000,000+  Free      0
# 3243      28860  Varies with device    100,000,000+  Free      0
# 3244      76604  Varies with device    100,000,000+  Free      0
# 3245      26189                5.3M     10,000,000+  Free      0
# 3246     739329  Varies with device     50,000,000+  Free      0
# 3247      45838                 16M     50,000,000+  Free      0
# 3248      25592                7.5M     10,000,000+  Free      0
# 3249      34126  Varies with device     10,000,000+  Free      0
# 3250       2394  Varies with device      5,000,000+  Free      0
# 3251     330468  Varies with device     10,000,000+  Free      0
# 3252          1                3.7M      1,000,000+  Free      0
# 3253     136874  Varies with device     10,000,000+  Free      0
# 3254       1236                5.8M        100,000+  Free      0
# 3255    7790693                 17M    500,000,000+  Free      0
# 3256     537554  Varies with device     10,000,000+  Free      0
# 3257     315585                8.5M     10,000,000+  Free      0
# 3258        142  Varies with device      1,000,000+  Free      0
# 3259      12215                9.1M      5,000,000+  Free      0
# 3260     127223                7.6M     10,000,000+  Free      0
# 3261       9602                2.5M    100,000,000+  Free      0
# 3262      24151                 15M     10,000,000+  Free      0
# ...         ...                 ...             ...   ...    ...
# 10472        19                3.0M          1,000+  Free      0
# 10473    134203                4.1M     10,000,000+  Free      0
# 10475       132                2.6M         50,000+  Free      0
# 10485         2                6.2M            100+  Free      0
# 10488        40                2.4M          5,000+  Free      0
# 10510         1                 20M             10+  Free      0
# 10517         1                2.5M            100+  Paid  $1.49
# 10531     12700                 10M        100,000+  Paid  $3.49
# 10566      1456                 15M         50,000+  Free      0
# 10580       148                9.2M         50,000+  Free      0
# 10591         3                 41M            500+  Free      0
# 10676         9                3.6M            500+  Free      0
# 10688      1916                364k        100,000+  Free      0
# 10727       222                 16M         50,000+  Free      0
# 10728    271908                8.1M     10,000,000+  Free      0
# 10732      3268                467k        100,000+  Free      0
# 10741      8484                1.7M      1,000,000+  Free      0
# 10746         9                 61M          1,000+  Free      0
# 10750      2531                3.3M        100,000+  Free      0
# 10756        58                2.5M          5,000+  Free      0
# 10757       422                 72M         50,000+  Free      0
# 10758     10786                4.3M      1,000,000+  Free      0
# 10759        17                 67k          1,000+  Free      0
# 10766       452                7.0M        100,000+  Free      0
# 10786       455                2.8M         50,000+  Free      0
# 10795      7339                4.0M        100,000+  Free      0
# 10796     61445                7.8M      1,000,000+  Free      0
# 10800       174                 12M          5,000+  Free      0
# 10807         2                4.2M            100+  Free      0
# 10817       885                8.0M        100,000+  Free      0
#
#       Content Rating Genres       Last Updated              Current Ver  \
# 3233        Everyone  Tools   February 1, 2018                  v3.7.93
# 3234        Everyone  Tools     August 3, 2018       Varies with device
# 3235        Everyone  Tools     August 4, 2018       Varies with device
# 3236        Everyone  Tools     August 6, 2018       Varies with device
# 3237        Everyone  Tools  November 21, 2014                  1.02.53
# 3238        Everyone  Tools   January 17, 2016       Varies with device
# 3239        Everyone  Tools      July 25, 2018                    3.1.2
# 3240        Everyone  Tools       June 8, 2018                   0.2.32
# 3241        Everyone  Tools       June 5, 2018       Varies with device
# 3242        Everyone  Tools  November 21, 2017       Varies with device
# 3243        Everyone  Tools      July 18, 2018       Varies with device
# 3244        Everyone  Tools      July 27, 2016       Varies with device
# 3245        Everyone  Tools      June 27, 2018  MyMetro_HTML_2.0_430029
# 3246        Everyone  Tools     April 17, 2018       Varies with device
# 3247        Everyone  Tools      July 25, 2018                    7.6.1
# 3248        Everyone  Tools      July 31, 2018          v8.0.1.8.0629.1
# 3249        Everyone  Tools      July 13, 2018       Varies with device
# 3250        Everyone  Tools  November 13, 2014       Varies with device
# 3251        Everyone  Tools       May 29, 2018       Varies with device
# 3252        Everyone  Tools   January 17, 2018           2.1.02.4477839
# 3253        Everyone  Tools      June 25, 2018       Varies with device
# 3254        Everyone  Tools       July 6, 2018                    8.1.6
# 3255        Everyone  Tools      July 30, 2018                4.5.28_ww
# 3256        Everyone  Tools     August 1, 2018       Varies with device
# 3257        Everyone  Tools      July 18, 2018            1.0.204375696
# 3258        Everyone  Tools     March 27, 2017       Varies with device
# 3259        Everyone  Tools     August 1, 2018                    1.7.4
# 3260        Everyone  Tools     August 3, 2018  v7.0.7.1.0625.1_06_0629
# 3261        Everyone  Tools       July 5, 2018                 6.0.61.5
# 3262        Everyone  Tools     August 6, 2018                   11.7.0
# ...              ...    ...                ...                      ...
# 10472       Everyone    NaN  February 11, 2018                   1.0.19
# 10473       Everyone  Tools     August 7, 2018                  6.06.14
# 10475       Everyone  Tools       May 17, 2017                    0.0.9
# 10485       Everyone  Tools  November 10, 2017                      1.0
# 10488       Everyone  Tools   October 31, 2017                    1.0.5
# 10510       Everyone  Tools    January 3, 2018                    1.1.2
# 10517       Everyone  Tools  December 21, 2015                       14
# 10531       Everyone  Tools     August 3, 2018                    3.2.5
# 10566       Everyone  Tools  November 14, 2016                      1.2
# 10580       Everyone  Tools    August 14, 2017                   1.0.18
# 10591       Everyone  Tools  December 12, 2017                      1.0
# 10676       Everyone  Tools  November 12, 2015                      1.4
# 10688       Everyone  Tools  December 31, 2015                    1.8.8
# 10727       Everyone  Tools      July 26, 2018                    2.2.4
# 10728       Everyone  Tools     August 2, 2018                    3.3.0
# 10732       Everyone  Tools  December 16, 2017                      6.6
# 10741       Everyone  Tools      July 22, 2018                   0.15.2
# 10746       Everyone  Tools       May 31, 2018                      1.9
# 10750       Everyone  Tools      July 30, 2017                    1.2.4
# 10756       Everyone  Tools      July 24, 2018               2017.07.24
# 10757       Everyone  Tools  February 23, 2018                    2.4.1
# 10758       Everyone  Tools   December 9, 2017                      5.0
# 10759       Everyone  Tools   January 29, 2016                      1.1
# 10766       Everyone  Tools      July 17, 2017            1.03.123.0713
# 10786       Everyone  Tools  February 28, 2017                      1.6
# 10795       Everyone  Tools       May 10, 2018                     1.74
# 10796       Everyone  Tools      July 26, 2018                  1.9.734
# 10800       Everyone  Tools      July 30, 2018                     6.04
# 10807       Everyone  Tools      April 9, 2018               1.283.0037
# 10817       Everyone  Tools   October 30, 2015               1.0.612928
#
#               Android Ver
# 3233           5.0 and up
# 3234   Varies with device
# 3235   Varies with device
# 3236   Varies with device
# 3237           4.4 and up
# 3238   Varies with device
# 3239           4.0 and up
# 3240           8.0 and up
# 3241   Varies with device
# 3242   Varies with device
# 3243   Varies with device
# 3244   Varies with device
# 3245           4.0 and up
# 3246   Varies with device
# 3247           4.1 and up
# 3248           4.2 and up
# 3249   Varies with device
# 3250   Varies with device
# 3251   Varies with device
# 3252           7.0 and up
# 3253   Varies with device
# 3254           4.2 and up
# 3255           4.1 and up
# 3256   Varies with device
# 3257           5.0 and up
# 3258   Varies with device
# 3259           7.0 and up
# 3260           5.0 and up
# 3261           7.0 and up
# 3262           4.1 and up
# ...                   ...
# 10472          4.0 and up
# 10473          4.4 and up
# 10475          2.3 and up
# 10485          4.0 and up
# 10488          2.1 and up
# 10510          4.1 and up
# 10517          4.0 and up
# 10531          5.0 and up
# 10566          4.4 and up
# 10580        4.0.3 and up
# 10591          4.2 and up
# 10676          4.0 and up
# 10688          2.1 and up
# 10727          4.4 and up
# 10728          4.0 and up
# 10732          2.0 and up
# 10741          6.0 and up
# 10746        4.0.3 and up
# 10750          6.0 and up
# 10756          4.1 and up
# 10757          4.4 and up
# 10758          4.0 and up
# 10759          4.0 and up
# 10766        4.0.3 and up
# 10786          6.0 and up
# 10795          4.1 and up
# 10796          4.1 and up
# 10800          4.4 and up
# 10807        2.3.3 and up
# 10817          5.0 and up
#
# [844 rows x 13 columns]

# %% [markdown]
# Similarmente existe o `.tail()`, que exibe por padrão as últimas 5 linhas do DataFrame:

# %%
## Colunas
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
## Excluir colunas que não vão ser utilizadas
df.drop(['Content Rating', 'Current Ver', 'Android Ver', 'Type' ], axis=1, inplace=True)
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs Price                     Genres  \
# 0      159   19M      10,000+     0               Art & Design
# 1      967   14M     500,000+     0  Art & Design;Pretend Play
# 2    87510  8.7M   5,000,000+     0               Art & Design
# 3   215644   25M  50,000,000+     0               Art & Design
# 4      967  2.8M     100,000+     0    Art & Design;Creativity
#
#        Last Updated
# 0   January 7, 2018
# 1  January 15, 2018
# 2    August 1, 2018
# 3      June 8, 2018
# 4     June 20, 2018

# %%
## Ou deixar apenas aquelas que serão utilizadas
df = df[['name', 'attack', 'defense', 'speed', 'generation']]

# %%
## Visualizando os tipos do dataset
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# A função `apply()` serve para aplicar funções que só funcione para valores únicos. Pode ser aplicada em Series e em DataFrames.

# %%
df['Last Updated'] = df['Last Updated'].apply(datetime.strptime, args=('%B %d, %Y',))

# %% [markdown]
# Quantas gerações de pokemons existem em nosso dataset? Você pode verificar a informação usando um método que lista os valores únicos numa coluna:

# %%
## Listando os valores únicos
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %% [markdown]
# Também parece interessante verificarmos a hegemoneidade da nossa amostra em relação as gerações. Pra tarefas de contar valores podemos sempre aproveitar de outro método disponível, o `.value_counts()`.

# %%
## Quantidade de valores para cada geração
df['Category'].value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   844
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# Name: Category, dtype: int64

# %% [markdown]
# Os valores contados também podem ser normalizados para expressar porcentagens:

# %%
## Quantidade de valores para cada geração (normalizado)
df['Category'].value_counts(normalize=True)
# Out:
# FAMILY                 0.181902
# GAME                   0.105525
# TOOLS                  0.077853
# MEDICAL                0.042708
# BUSINESS               0.042432
# PRODUCTIVITY           0.039111
# PERSONALIZATION        0.036159
# COMMUNICATION          0.035698
# SPORTS                 0.035421
# LIFESTYLE              0.035237
# FINANCE                0.033761
# HEALTH_AND_FITNESS     0.031455
# PHOTOGRAPHY            0.030901
# SOCIAL                 0.027212
# NEWS_AND_MAGAZINES     0.026105
# SHOPPING               0.023983
# TRAVEL_AND_LOCAL       0.023799
# DATING                 0.021585
# BOOKS_AND_REFERENCE    0.021308
# VIDEO_PLAYERS          0.016142
# EDUCATION              0.014390
# ENTERTAINMENT          0.013744
# MAPS_AND_NAVIGATION    0.012637
# FOOD_AND_DRINK         0.011715
# HOUSE_AND_HOME         0.008117
# LIBRARIES_AND_DEMO     0.007841
# AUTO_AND_VEHICLES      0.007841
# WEATHER                0.007564
# ART_AND_DESIGN         0.005996
# EVENTS                 0.005904
# PARENTING              0.005535
# COMICS                 0.005535
# BEAUTY                 0.004889
# Name: Category, dtype: float64

# %% [markdown]
# Agrupar os dados se baseando em certos critérios é outro processo que o pandas facilita bastante com o `.groupby()`.
#
# Abaixo agrupamos o nosso DataFrame pelos valores da coluna `"generation"`, e em seguida aplicamos o `.mean()` ou `.agg('mean')` para termos um objeto GroupBy com informação das médias agrupadas pelos valores da coluna geração.

# %%
## Agrupando pelas gerações
df.groupby('Category').mean()
# Out:
#                        Rating       Reviews
# Category
# ART_AND_DESIGN       4.358065  2.637600e+04
# AUTO_AND_VEHICLES    4.190411  1.369019e+04
# BEAUTY               4.278571  7.476226e+03
# BOOKS_AND_REFERENCE  4.346067  9.506090e+04
# BUSINESS             4.121452  3.033598e+04
# COMICS               4.155172  5.638793e+04
# COMMUNICATION        4.158537  2.107138e+06
# DATING               3.970769  3.115931e+04
# EDUCATION            4.389032  2.538191e+05
# ENTERTAINMENT        4.126174  3.971688e+05
# EVENTS               4.435556  2.515906e+03
# FAMILY               4.192272  2.080255e+05
# FINANCE              4.131889  4.795281e+04
# FOOD_AND_DRINK       4.166972  6.994748e+04
# GAME                 4.286326  1.385859e+06
# HEALTH_AND_FITNESS   4.277104  1.111253e+05
# HOUSE_AND_HOME       4.197368  4.518619e+04
# LIBRARIES_AND_DEMO   4.178462  1.220139e+04
# LIFESTYLE            4.094904  3.372457e+04
# MAPS_AND_NAVIGATION  4.051613  2.237902e+05
# MEDICAL              4.189143  3.425432e+03
# NEWS_AND_MAGAZINES   4.132189  1.922292e+05
# PARENTING            4.300000  1.597218e+04
# PERSONALIZATION      4.335987  2.279238e+05
# PHOTOGRAPHY          4.192114  6.373631e+05
# PRODUCTIVITY         4.211396  2.691438e+05
# SHOPPING             4.259664  4.424662e+05
# SOCIAL               4.255598  2.105903e+06
# SPORTS               4.223511  1.844536e+05
# TOOLS                4.044490  3.236790e+05
# TRAVEL_AND_LOCAL     4.109292  2.427051e+05
# VIDEO_PLAYERS        4.063750  6.307439e+05
# WEATHER              4.244000  1.781065e+05

# %% [markdown]
# É comum queremos aplicar uma função qualquer aos dados, ou à parte deles, neste caso o pandas fornece o método `.apply`. Por exemplo, para deixar os nomes dos pokemons como apenas as suas três primeiras letras:

# %%
## Aplicação do método apply

# %% [markdown]
# Ou de um jeito mais prático, usando uma função lambda:

# %%
## Aplicação do método apply

# %% [markdown]
# Uma das tarefas na qual o pandas é reconhecidamente poderoso é a habilidade de tratar dados incompletos.
# Por muitos motivos pode haver incompletude no dataset, o `np.nan` é um valor especial definido no Numpy, sigla para Not a Number, o pandas preenche células sem valores em um DataFrame lido com `np.nan`.
#
# Vamos criar um novo dataframe usando as 5 primeiras linhas do nosso original, usando o já visto `.head()`. Abaixo é usado o `.replace` para substituir um valor específico por um `NaN`.

# %%
## Utilizando o replace()

# %% [markdown]
# O pandas simplifica a remoção de quaiquer linhas ou colunas que possuem um `np.nan`, por padrão o `.dropna()` retorna as linhas que não contém um NaN:

# %%
## Excluindo linhas com nan

# %% [markdown]
# Preencher todos os valores NaN por um outro específico também é bastante simples:

# %%
## Subistindo valores nan

# %% [markdown]
# ## Visualização de dados com Pandas

# %% [markdown]
# Partiremos agora para visualização de dados com o pandas. Os métodos de visualização do pandas são construídos com base no matplotlib para exploração rápida dos dados.
#
# Comecemos verificando que tanto Series como DataFrame possuem um método `.plot()` que também é um atributo e pode ser encadeado para gerar visualização de diversos tipos, como histograma, área, pizza e dispersão, com respectivamente  `.hist()`, `.area()`, `.pie()` e  `.scatter()`, além de vários outros.
#
# Vamos verificar a distribuição das velocidades usando o encadeamento `.plot.hist()`:

# %%
## Histograma

# %% [markdown]
# Por padrão esse método usa 10 bins, ou seja, divide os dados em 10 partes, mas é claro que podemos especificar um valor para a plotagem. Abaixo, além de especificar a quantidade de bins, também especifiquei a cor das bordas como preta, que por padrão é transparente.

# %%
## Histograma

# %% [markdown]
# Podemos usar os valores de contagem de cada geração como exemplo de dado para um plot tanto de barras verticais quando de barras horizontais, para verificar visualmente esses dados:

# %%
## Gráfico de barras verticais

# %%
## Gráfico de barras horizontais

# %% [markdown]
# Os métodos são flexíveis o suficiente para aceitarem argumentos como um título para a imagem:

# %%
## Adicionando título

# %% [markdown]
# Um gráfico de dispersão usando um DataFrame pode ser usado especificando-se quais colunas usar como dados no eixo x e y:

# %%
## Gráfico de dispersão

# %% [markdown]
# A coluna `is_legendary` diz se o pokémon é legendário ou não, também se pode ver a contagem e distribuição usando outros métodos de plotagem oferecidos pelo pandas:

# %%
## Gráfico de pizza

# %% [markdown]
# ## Salvando DataFrame

# %% [markdown]
# Finalmente, a tarefa de salvar seu DataFrame externamente para um formato específico é feita com a mesma simplicidade que a leitura de dados é feita no pandas, pode-se usar, por exemplo, o método `to_csv`, e o arquivo será criado com os dados do DataFrame:

# %%
## Salvando um novo DataFrame no computador
